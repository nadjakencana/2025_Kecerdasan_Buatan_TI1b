# %% [markdown]
# <a href="https://colab.research.google.com/github/nadjakencana/2025_Kecerdasan_Buatan_TI1b/blob/main/JobSheet_4_Kecerdasan_Buatan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Latihan 1 Jobsheet 4 Kecerdasan Buatan

# %%
import pandas as pd

df = pd.read_csv('./data.csv')
print(df.to_string())
df
pd.options.display.max_rows
pd.options.display.max_rows = 9999

df = pd.read_csv('./data.csv')
df

# %%
import pandas as pd

df = pd.read_json('./data.json')
print(df.to_string())

# %%
df = pd.read_csv('./data.csv', sep=',', header=0)
df

# %%
data = {
  "Duration": { "0":60, "1":60, "2":60, "3":45 },
  "Pulse": { "0":110, "1":117, "2":103, "3":109 },
  "Maxpulse": { "0":130, "1":145, "2":135, "3":175 },
  "Calories": { "0":409, "1":479, "2":340, "3":282 }
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282

# %% [markdown]
# # Latihan 2 Jobsheet 4 Kecerdasan Buatan

# %%
import pandas as pd

li = [1, 7, 2]
se = pd.Series(li)
print(se)

# %%
li = [1, 7, 2]
se = pd.Series(li)
print(se[0])

# %%
li = [1, 7, 2]
se = pd.Series(li, index = ['x', 'y', 'z'])
print(se['x'])

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
se = pd.Series(calories)
print(se)

# %% [markdown]
# # Latihan 3 JobSheet 4 Kecerdasan Buatan

# %%
import pandas as pd

df = pd.DataFrame(data={"Nama": ["Budi", "Joko", "Adi"], "Umur": [12, 13, 15], "Kelas": [6, 7, 8]})
df
df.columns
df.columns.values[0] = "Nama Singkat"
df
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.iloc[0:2, 0:1]
df.iloc[0:2, 0:2]
df.iloc[:, 0:2]
df.loc[0:2, ['calories']]
df.loc[0:2, ['calories', 'duration']]
df['calories']
df['calories'][0]
df[['calories']]
df[['calories']].loc[[0, 1]]
# Out:
#    calories
# 0       420
# 1       380

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ['day1', 'day2', 'day3'])
print(df)
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df = pd.read_csv('./data.csv')
print(df)
df
df.head()
df.tail()
df.head(10)
df.shape
df.dtypes

# %%
df.info()
df.describe()
print(df['Calories'].mean(), df['Calories'].median(), df['Calories'].mode()[0])
df.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# 375.79024390243904 318.6 300.0
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# # Praktikum JobSheet 4 Kecerdasan Buatan

# %%
import pandas as pd

#Mengubah DataSet menjadi Data Frame
df = pd.read_csv('./epl-goalScorer(20-21).csv')

# %%
# Ambil 5 data pertama
print(df.head())
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %%
# Tampilkan Jumlah Barsi dan Kolom
print(df.shape)
# Out:
# (522, 19)

# %%
# Tampilkan tipe data dari tiap kolom
print(df.dtypes)
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %%
# Jumlah Goal tiap Pemain
print(df[['player_name', 'goals']])
# Out:
#                    player_name  goals
# 0                   Harry Kane     23
# 1                Mohamed Salah     22
# 2              Bruno Fernandes     18
# 3                Son Heung-Min     17
# 4              Patrick Bamford     17
# 5        Dominic Calvert-Lewin     16
# 6                  Jamie Vardy     15
# 7                Ollie Watkins     14
# 8               Ilkay Gündogan     13
# 9          Alexandre Lacazette     13
# 10               Callum Wilson     12
# 11           Kelechi Iheanacho     12
# 12                  Danny Ings     12
# 13                  Chris Wood     12
# 14               Wilfried Zaha     11
# 15             Marcus Rashford     11
# 16                  Sadio Mané     11
# 17                 Gareth Bale     11
# 18             Matheus Pereira     11
# 19   Pierre-Emerick Aubameyang     10
# 20             Michail Antonio     10
# 21           Christian Benteke     10
# 22             Raheem Sterling     10
# 23              Edinson Cavani     10
# ...

# %%
# DAtaframe berisi kolom tertentu
print(df[['player_name', 'goals', 'position', 'team_title', 'yellow_cards']])
# Out:
#                    player_name  goals position                     team_title  \
# 0                   Harry Kane     23        F                      Tottenham
# 1                Mohamed Salah     22    F M S                      Liverpool
# 2              Bruno Fernandes     18      M S              Manchester United
# 3                Son Heung-Min     17    F M S                      Tottenham
# 4              Patrick Bamford     17      F S                          Leeds
# 5        Dominic Calvert-Lewin     16      F S                        Everton
# 6                  Jamie Vardy     15      F S                      Leicester
# 7                Ollie Watkins     14        F                    Aston Villa
# 8               Ilkay Gündogan     13      M S                Manchester City
# 9          Alexandre Lacazette     13    F M S                        Arsenal
# 10               Callum Wilson     12      F S               Newcastle United
# ...

# %%
# Pemain Liverpool
print(df[df['team_title'] == 'Liverpool'])
# Out:
#      Unnamed: 0    id              player_name  games  time  goals         xG  \
# 1             1  1250            Mohamed Salah     37  3085     22  20.250847
# 16           16   838               Sadio Mané     35  2805     11  14.828548
# 26           26   482          Roberto Firmino     36  2882      9  12.860213
# 30           30  6854               Diogo Jota     19  1114      9   7.057721
# 116         116   771      Georginio Wijnaldum     38  2961      2   2.817427
# 130         130  1791   Trent Alexander-Arnold     36  3040      2   2.593060
# 161         161   229         Thiago Alcántara     24  1865      1   1.211306
# 162         162   332               Joel Matip     10   701      1   0.784475
# 172         172   605         Jordan Henderson     21  1710      1   1.135798
# 187         187   833          Virgil van Dijk      5   370      1   0.553383
# 192         192   966  Alex Oxlade-Chamberlain     13   238      1   0.300651
# ...

# %%
# Pemain arsenal
print(df[df['team_title'] == 'Arsenal'])
# Out:
#      Unnamed: 0    id                player_name  games  time  goals  \
# 9             9  3277        Alexandre Lacazette     30  1928     13
# 19           19   318  Pierre-Emerick Aubameyang     28  2254     10
# 36           36  5656               Nicolas Pepe     28  1512      8
# 65           65  7322                Bukayo Saka     31  2561      5
# 140         140  5613                    Gabriel     22  1904      2
# 146         146  6482              Eddie Nketiah     17   405      2
# 149         149  7230           Emile Smith-Rowe     19  1382      2
# 152         152  7752         Gabriel Martinelli     13   577      2
# 160         160   204               Granit Xhaka     30  2447      1
# 164         164   492            Héctor Bellerín     25  2098      1
# 165         165   496             Mohamed Elneny     23  1540      1
# 180         180   700                    Willian     25  1413      1
# 203         203  1676                 David Luiz     20  1410      1
# ...

# %%
# Top 10 kartu kuning
top_yellow = df.sort_values(by='yellow_cards', ascending=False)
print(top_yellow.head(10))
# Out:
#      Unnamed: 0    id            player_name  games  time  goals        xG  \
# 106         106  7723            John McGinn     37  3330      3  2.166595
# 157         157  9040        Conor Gallagher     30  2529      2  1.542326
# 125         125  1687          Harry Maguire     34  3049      2  1.484337
# 259         259  8719        Kalvin Phillips     29  2435      1  0.388623
# 110         110   343  Pierre-Emile Højbjerg     38  3420      2  1.137927
# 216         216  5549       Luka Milivojevic     31  2374      1  2.213461
# 397         397  6062           Isaac Hayden     24  1946      0  0.614847
# 218         218  5609          Yves Bissouma     35  3031      1  1.055967
# 448         448  7708         John Lundstram     28  2034      0  1.875774
# 399         399  6122           Douglas Luiz     33  2807      0  1.318834
#
#      assists        xA  shots  key_passes  yellow_cards  red_cards position  \
# ...

# %%
# Top 10 Kartu merah
top_red = df.sort_values(by='red_cards', ascending=False)
print(top_red.head(10))
# Out:
#      Unnamed: 0    id          player_name  games  time  goals        xG  \
# 61           61  6048           Lewis Dunk     32  2844      5  2.699258
# 488         488  8864         Matthew Cash     28  2389      0  0.247891
# 493         493  8940     Antonee Robinson     28  2158      0  0.467749
# 21           21   606    Christian Benteke     30  1824     10  7.457401
# 18           18  7153      Matheus Pereira     33  2594     11  6.948317
# 476         476  8511  Alexandre Jankewitz      2     2      0  0.000000
# 25           25  8288         Tomas Soucek     37  3330     10  8.936490
# 443         443  7703            John Egan     30  2538      0  0.466965
# 433         433  7298            Ben White     35  3118      0  0.479218
# 421         421  6852         Matt Doherty     17  1228      0  0.363882
#
#      assists        xA  shots  key_passes  yellow_cards  red_cards position  \
# 61         0  0.830638     31          10             5          2        D
# ...
